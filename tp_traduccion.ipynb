# %% [markdown]
# # TP Introducción
# ---

# %% [markdown]
# ## Lenguaje a crear (completar)

# %% [markdown]
# ### Alfabeto:

# %%
""" 
El alfabeto del lenguaje MiniCalc está compuesto por el conjunto de símbolos básicos a partir de los cuales se construyen los programas.

Σ = { a-z, 0-9, +, -, =, ;, espacio }

a-z → letras minúsculas para identificadores
0-9 → dígitos para números
+, - → operadores aritméticos
= → asignación
== → comparación (se forma combinando dos símbolos =)
; → fin de sentencia
espacio → separador entre tokens

"""

# %% [markdown]
# ### Objetivo:
#     - 👉 ¿Para qué existe el lenguaje?
#     - 👉 ¿Qué problema resuelve?

# %%
"""
El objetivo del lenguaje MiniCalc es proporcionar un medio sencillo para la definición y evaluación de expresiones aritméticas 
básicas, incorporando la posibilidad de tomar decisiones mediante estructuras condicionales. 
Esto permite asignar valores a variables en función del resultado de condiciones lógicas simples.
"""

# %% [markdown]
# ### Alcance:

# %%
"""
- El lenguaje MiniCalc permite la asignación de valores a variables, el uso de números enteros positivos y la ejecución de operaciones 
aritméticas básicas como suma y resta. Además, incorpora estructuras condicionales del tipo if, que permiten ejecutar sentencias en 
función del cumplimiento de una condición.   
- Las condiciones admiten comparaciones de igualdad entre expresiones numéricas.
- El lenguaje no contempla estructuras de repetición (bucles), funciones, manejo de errores, ni operaciones avanzadas como multiplicación 
o división. 
- Tampoco permite el uso de números negativos, números decimales ni otros tipos de datos. 
- No se incluye la estructura else ni el anidamiento de condicionales.
"""

# %% [markdown]
# ### Especificaciones léxicas: Define las unidades básicas del lenguaje (como palabras).

# %%
"""
IDENTIFICADOR → letra (letra | número)*
NUMERO → dígito+
OPERADOR → + | -
ASIGNACION → =
COMPARADOR → ==
PALABRAS CLAVE → if, then
FIN_SENTENCIA → ;
"""

# %% [markdown]
# ### Especificaciones sintácticas: Define cómo se combinan los tokens. BNF (Backus-Naur Form)

# %%
"""
<programa> ::= <sentencia>+

<sentencia> ::= <asignacion> | <condicional>

<asignacion> ::= <identificador> "=" <expresion> ";"

<condicional> ::= "if" <condicion> "then" <asignacion>

<condicion> ::= <expresion> "==" <expresion>

<expresion> ::= <numero>
              | <numero> "+" <numero>
              | <numero> "-" <numero>

<identificador> ::= letra (letra | número)*
<numero> ::= dígito+
"""

# %% [markdown]
# ### Especificaciones semánticas: Explica el significado de lo que escribís.
#
# - Tipos:
#     - Semántica informal → en palabras
#     - Semántica formal → matemática (más avanzada)

# %%
Una asignación evalúa la expresión y guarda el resultado en la variable.
Una expresión: Se evalúa de izquierda a derecha.
Solo permite suma y resta entre números.
Un condicional (if):
Evalúa la condición.
Si es verdadera, ejecuta la asignación.
Si es falsa, no ejecuta nada.
Una condición:
Compara dos expresiones usando ==.
Devuelve verdadero o falso.
